# %%
from huggingface_hub import HfApi

# %%
api = HfApi()

# %%
api.upload_large_folder(repo_id=r"AaronLoera/QR_Data",
                        folder_path=r"C:\Users\loera\Documents\Datasets\Phishing_URLs\qr_codes\qr_images",
                        repo_type=r"dataset")
